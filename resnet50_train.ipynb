# %% [markdown]
# <a href="https://colab.research.google.com/github/Tianea2160/PythonPractice/blob/master/resnet50_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sebastianbk/finetuned-resnet50-keras.git
# Out:
# Cloning into 'finetuned-resnet50-keras'...
# remote: Enumerating objects: 12, done.
# remote: Total 12 (delta 0), reused 0 (delta 0), pack-reused 12
# Unpacking objects: 100% (12/12), done.

# %% [markdown]
# # **코드 상으로 수정해야하는 것들**
#
# 학습 이미지를 넣기 위해서 오픈 소스에서 몇가지 수정해야할 것들이 있습니다.
# 예전 버전들에 초점이 맞추어져서 deprecated된것 들도 있습니다.
#
# 1. resnet50_train.py에서 전역 변수로 선언되어 있는 DATA_DIR에 저희가 사용하는 이미지 셋을 넣어야합니다.
#
# 이미지 폴더 자체를 github 폴더에 넣으면 정말 좋겠지만 저희는 코랩에서 사용하기 때문에 구글 드라이브 연동을 사용할 것이고 절대경로로 지정해주는 것이 더 편하기 때문입니다.
#
#
#
# Example (resnet50_train.py)
# ~~~
# DATA_DIR = '/content/drive/MyDrive/dataset'
# ~~~
#
# 2. dataset 폴더안에 train, valid 폴더가 있어야합니다.
# 만약에 train, test 또는 train, val 로 되어 있다면 resnet50_train.py 파일안에서 경로를 수정해주세요.
#
#
# 3. 그리고 import 하는 부분을 아래와 같이 교체해줍니다.
# 케라스의 최적 함수를 사용하는 부분이 오류가 나기때문에 확실한 프레임워크 경로 지정을 하는 것입니다.
#
# Example (resnet50_train.py)
# ~~~
# from tensorflow import keras
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.layers import Dense
# from keras.models import Model
# from tensorflow.keras.optimizers import Adam # - Works
# from keras.preprocessing import image
# ~~~

# %%
# !python3 /content/finetuned-resnet50-keras/resnet50_train.py
# Out:
# Found 3500 images belonging to 7 classes.
# Found 700 images belonging to 7 classes.
# 2022-04-12 01:34:02.663347: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /content/finetuned-resnet50-keras/resnet50_train.py:48: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   finetuned_model.fit_generator(batches, steps_per_epoch=num_train_steps, epochs=1000, callbacks=[early_stopping, checkpointer], validation_data=val_batches, validation_steps=num_valid_steps)
# Epoch 1/1000
#  24/109 [=====>........................] - ETA: 8:09 - loss: 1.9447 - accuracy: 0.1523
